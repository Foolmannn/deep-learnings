# %%
import torch

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0, requires_grad=True) # as we need the dL/dw asn dL/db 
b = torch.tensor(0.0, requires_grad=True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z = w*x + b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
# Binary Cross-Entropy Loss for scalar
def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8  # To prevent log(0)
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
loss = binary_cross_entropy_loss(y_pred, y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %% [markdown]
# # so this is how easy to calculate the gradient in backward pass using autograd

# %% [markdown]
# # so far we have used the scaler as input We can use vector very easily

# %%
# x= torch.tensor([1,2,3,4,5],requires_grad=True)  Only Tensors of floating point and complex dtype can require gradients
x= torch.tensor([1.0,2.0,3.0],requires_grad=True)
print(x)
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad  # so we can get the gradient of the vectors too
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %% [markdown]
# # this is what is being done internally
#
# ![image.png](attachment:image.png)
