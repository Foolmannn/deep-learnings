# %%
import numpy as np
import torch

a= np.array([1,2,3,4,5,6])

b = torch.tensor([1,2,3,4,5,6])
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## tensor to numpy arrays

# %%
c= b.numpy()
print(type(c))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## numpy to tensors

# %%
d = torch.from_numpy(a)
d # now this d is tensor
# Out:
# tensor([1, 2, 3, 4, 5, 6])
