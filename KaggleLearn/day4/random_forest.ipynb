# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error


home_data = pd.read_csv('../day1/input/train.csv')

y = home_data.SalePrice

features = ['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']
X = home_data[features]

train_X,val_X,train_y,val_y = train_test_split(X,y,random_state=1)


iowa_home_model = DecisionTreeRegressor(random_state=1)

iowa_home_model.fit(train_X,train_y)


# Make validation predictions and calculate mean absolute error
val_predictions = iowa_home_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("Validation MAE when not specifying max_leaf_nodes: {:,.0f}".format(val_mae))

# Using best value for max_leaf_nodes as we have previous found 
iowa_home_model = DecisionTreeRegressor(max_leaf_nodes=100, random_state=2)
iowa_home_model.fit(train_X, train_y)
val_predictions = iowa_home_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("Validation MAE for best value of max_leaf_nodes: {:,.0f}".format(val_mae))
# Out:
# Validation MAE when not specifying max_leaf_nodes: 29,653
# Validation MAE for best value of max_leaf_nodes: 27,467

# %% [markdown]
# Using the Random Forest
# Data science isn't always this easy. But replacing the decision tree with a Random Forest is going to be an easy win.

# %% [markdown]
# Step 1: Use a Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

#Defing the model and setting the random state

rf_model = RandomForestRegressor(random_state=2)

# fitting our model 

rf_model.fit(train_X,train_y)

# calculating the mean absuolute error for Random forest model on the validataion data 

rf_val_predictions = rf_model.predict(val_X)

rf_val_mae = mean_absolute_error(val_y,rf_val_predictions)

print("Validation MAE for Random Forest Model : {}".format(rf_val_mae))
# Out:
# Validation MAE for Random Forest Model : 22512.698301369863

# %%
# printing first few validataion predictions
# print(rf_model.predict(val_X.head(10)))


#printing top few actual prices from the validataion data
# print(val_y.head(10))

results = val_X.copy()
val_predictions= rf_model.predict(val_X)


results["Actual"] = val_y
results["Predicted"] = rf_val_predictions
results["Error"] = val_y-rf_val_predictions

print(results.head(10))
# Out:
#       LotArea  YearBuilt  1stFlrSF  2ndFlrSF  FullBath  BedroomAbvGr  \
# 258     12435       2001       963       829         2             3
# 267      8400       1939      1052       720         2             4
# 288      9819       1967       900         0         1             3
# 649      1936       1970       630         0         1             1
# 1233    12160       1959      1188         0         1             3
# 167     10562       2007      1610       551         1             3
# 926     11999       2003      1234      1140         2             4
# 831      3180       2005       520       600         2             2
# 1237    12393       2004       847      1101         2             4
# 426     12800       1989      1644         0         2             2
#
#       TotRmsAbvGrd  Actual  Predicted     Error
# 258              7  231500  191904.95  39595.05
# 267              8  179500  146745.00  32755.00
# 288              5  122000  130501.00  -8501.00
# ...

# %% [markdown]
# as we can see compared to previous best decision tree regressor using optimum max leaf nodes this is  better in an aspect  as there is no issue of underfitting and overfitting
